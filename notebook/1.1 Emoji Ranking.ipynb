# %%
import pandas as pd
import sqlite3
import emoji
from collections import Counter

from matplotlib.pyplot import yscale, xscale, title, plot
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
def read_sql():
    df = __read_sql()
    df = __select_taipei_area(df)
    df = __clean_raw_dataframe(df)
    return df

# read raw data from sql
def __read_sql():
    con = sqlite3.connect('../data/InstagramPost.sqlite')
    con2 = sqlite3.connect('../data/InstagramPost2.sqlite')
    con3 = sqlite3.connect('../data/InstagramPost3.sqlite')
    SQL = pd.read_sql_query('select * from InstagramPost', con)
    SQL2 = pd.read_sql_query('select * from InstagramPost_table2', con)
    SQL3 = pd.read_sql_query('select * from InstagramPost_table3', con)
    SQL4 = pd.read_sql_query('select * from InstagramPost_table4', con)
    SQL5 = pd.read_sql_query('select * from InstagramPost_table2', con2)
    SQL6 = pd.read_sql_query('select * from InstagramPost', con3)

    # concat SQL tables
    SQL = pd.concat([SQL, SQL2, SQL3, SQL4, SQL5, SQL6]).drop_duplicates()
    del SQL2, SQL3, SQL4, SQL5, SQL6
    SQL['datetime'] = pd.to_datetime(SQL.date, unit='s')
    instagram2016 = SQL[SQL.datetime.dt.year == 2016]
    del SQL
    return instagram2016

# select taipei area
def __select_taipei_area(df):
    # 信义松山
    lat_min, lat_max = 25.028791, 25.06338
    lng_min, lng_max = 121.54733, 121.59

    df['lat'] = df.lat.astype(float)
    df['lng'] = df.lng.astype(float)

    lat_bound = df.lat.between(lat_min, lat_max)
    lng_bound = df.lng.between(lng_min, lng_max)
    df = df[lat_bound & lng_bound]
    return df

# clean datafrome
def __clean_raw_dataframe(df):
    df = df[['location_id', 'location_name', 'lat', 'lng', 'caption', 'comments',
             'date', 'media_id', 'is_video', 'likes', 'owner_id', 'thumbnail_src',
             'display_src', 'datetime']].reset_index().drop(columns='index')
    return df

# %%
def emoji_tokenize(text):
    token = ''.join(c for c in text if c in emoji.UNICODE_EMOJI)
    return token

def create_emoji_column(df):
    df['emoji'] = df['caption'].apply(emoji_tokenize)
    return df

def count_emoji(text, freq):
    '''
    return the highest used emoji
    it only works for text including emoji only
    '''
    c = Counter(text)
    return c.most_common(freq)

def count_emoji_location(df, freq=1):
    '''
    group by location
    return df including the most used emoji
    '''
    df = create_emoji_column(df)
    gb = df.groupby('location_name')
    loc_df = pd.DataFrame(gb['emoji'].sum())
    loc_df['count'] = loc_df['emoji'].apply(lambda x: count_emoji(x, freq))
    return loc_df

# %% [markdown]
# # 1. Import Data

# %%
ig2016 = read_sql()

# %%
ig_emoji = count_emoji_location(ig2016, 10).reset_index()
ig_emoji.head()
# Out:
#                    location_name  \
# 0                      1/10 Cake
# 1                 10 Square Cafe
# 2  1001 Nights Taipei (一千零一夜水煙館)
# 3                 101 Night Club
# 4                       101♥ ♥ ♥
#
#                                                emoji  \
# 0  📍🏡💰🔆🔆💡😂🍵💗🥝🍊🍇🍈🌬☺🍰🍰🍰😘🎉💪😋📍🏡💰🔆🔆💡😂🍵💗👍💯🍋😋🎄😩😋🙈😋💦♥😳⭐🎉🎄...
# 1  😘❤👼✨✨❤👼‼👍✨💛💚✨🎄✨✨💚❤💚🎉💚🎄🎁🎄💚👭😂😘💋❤🎄❤💚✨🎉🎉🎉💚🍾👍✨💚🎄💋🎄❤...
# 2  🤡🤡🤡🙄🍟👌😜😅😍😅🤔🤔🕴🍷💓🍵🎉❤🎄🎄🎄🚩🍷🍷🍷💕🚩🌬🌬🌬🙈🙈🙈🚩🍷🍸🍹⭐⭐⭐⭐⭐⭐✨✨👩...
# 3                                                🍻🍾❤
# 4                          😏☕☕😭♥❤💖💖❓❓✨✨👭😘🌃🌠🌌🎆😜👭😂😂😂👉👈
#
#                                                count
# 0  [(🍰, 23), (✨, 10), (😋, 9), (😍, 9), (😂, 8), (🍴,...
# 1  [(❤, 72), (✨, 50), (😍, 24), (💕, 22), (🎄, 20), ...
# 2  [(😂, 78), (❤, 71), (🍻, 46), (💕, 38), (🍸, 36), ...
# 3                           [(🍻, 1), (🍾, 1), (❤, 1)]
# 4  [(😂, 3), (☕, 2), (💖, 2), (❓, 2), (✨, 2), (👭, 2...

# %% [markdown]
# # Count Emoji

# %%
def count_all_emoji(df):
    '''
    return the most common emoji in Taipei
    '''
    df = create_emoji_column(df)
    emoji_text = df.emoji.str.cat()
    counter = Counter(emoji_text)
    return counter

# %%
emoji_counter = count_all_emoji(ig2016)

# %%
emoji_counter.most_common(10)
# Out:
# [('❤', 62631),
#  ('😂', 58929),
#  ('😋', 38195),
#  ('💕', 34469),
#  ('😍', 33449),
#  ('👍', 24454),
#  ('😭', 19768),
#  ('✨', 18925),
#  ('😘', 16189),
#  ('🎄', 15085)]

# %% [markdown]
# # Most used Emoji

# %%
# take out 10 most common emoji
# change rank into column
def change_rank_to_column(df, ktop):
    '''
    ktop -> how many column you need to build up
    '''
    ktop_counter = 0
    while ktop_counter < ktop:
        df['%s_emoji' % ktop_counter] = df['count'].apply(lambda x: x[ ktop_counter ][0] if ( len(x) > ktop_counter) else None)
        df['%s_value' % ktop_counter] = df['count'].apply(lambda x: x[ ktop_counter ][1] if ( len(x) > ktop_counter) else 0)
        ktop_counter += 1
    return df

# %%
ig_emoji = change_rank_to_column(ig_emoji, 5)

# %%
ig_emoji.head()
# Out:
#                    location_name  \
# 0                      1/10 Cake
# 1                 10 Square Cafe
# 2  1001 Nights Taipei (一千零一夜水煙館)
# 3                 101 Night Club
# 4                       101♥ ♥ ♥
#
#                                                emoji  \
# 0  📍🏡💰🔆🔆💡😂🍵💗🥝🍊🍇🍈🌬☺🍰🍰🍰😘🎉💪😋📍🏡💰🔆🔆💡😂🍵💗👍💯🍋😋🎄😩😋🙈😋💦♥😳⭐🎉🎄...
# 1  😘❤👼✨✨❤👼‼👍✨💛💚✨🎄✨✨💚❤💚🎉💚🎄🎁🎄💚👭😂😘💋❤🎄❤💚✨🎉🎉🎉💚🍾👍✨💚🎄💋🎄❤...
# 2  🤡🤡🤡🙄🍟👌😜😅😍😅🤔🤔🕴🍷💓🍵🎉❤🎄🎄🎄🚩🍷🍷🍷💕🚩🌬🌬🌬🙈🙈🙈🚩🍷🍸🍹⭐⭐⭐⭐⭐⭐✨✨👩...
# 3                                                🍻🍾❤
# 4                          😏☕☕😭♥❤💖💖❓❓✨✨👭😘🌃🌠🌌🎆😜👭😂😂😂👉👈
#
#                                                count 0_emoji  0_value 1_emoji  \
# 0  [(🍰, 23), (✨, 10), (😋, 9), (😍, 9), (😂, 8), (🍴,...       🍰       23       ✨
# 1  [(❤, 72), (✨, 50), (😍, 24), (💕, 22), (🎄, 20), ...       ❤       72       ✨
# 2  [(😂, 78), (❤, 71), (🍻, 46), (💕, 38), (🍸, 36), ...       😂       78       ❤
# 3                           [(🍻, 1), (🍾, 1), (❤, 1)]       🍻        1       🍾
# 4  [(😂, 3), (☕, 2), (💖, 2), (❓, 2), (✨, 2), (👭, 2...       😂        3       ☕
#
#    1_value 2_emoji  2_value 3_emoji  3_value 4_emoji  4_value
# 0       10       😋        9       😍        9       😂        8
# 1       50       😍       24       💕       22       🎄       20
# 2       71       🍻       46       💕       38       🍸       36
# 3        1       ❤        1    None        0    None        0
# 4        2       💖        2       ❓        2       ✨        2

# %%
# drop value not include emoji
ig_emoji = ig_emoji.dropna(how='any').sort_values('1_value', ascending=False)

# %%
# drop value < 500
ig_emoji[ig_emoji['1_value'] > 300]
# Out:
#                                      location_name  \
# 94                                       BELLAVITA
# 628                    TAIPEI 101 MALL 台北 101 購物中心
# 59                                       ATT 4 FUN
# 996                                          信義區商圈
# 634                                  TICC 台北國際會議中心
# 2831                        點點心台灣 Dimdimsum Taiwan
# 1908                            松山文創園區 SCCP Taipei
# 490                                     Okey Dokey
# 785                                    YumYum Deli
# 398                                   M-Palace 樂晴店
# 1690                            微風信義 Breeze Xin Yi
# 2741                                       饒河街觀光夜市
# 1252                                          台北東區
# 2298                                     統一時代百貨台北店
# 584                                 September Café
# 1361                                          四四南村
# 483                              O Rose 法式天然高品質冰淇淋
# 1322                                     和茗甘味處-忠孝店
# 213                                        Elektro
# 1779                               新光三越台北信義新天地 A11
# 1385  國立國父紀念館National Dr.Sun Yat-sen Memorial Hall
# 414             Mandarin Oriental, Taipei 台北文華東方酒店
# 142                                     COMMUNE A7
# 1166                                      台北101觀景台
# 615                          Street Churros Taiwan
# 2054                   河床工作室 -  Pâtisserie Rivière
# 577                    Sarabeth's Taiwan 台北敦化sogo店
# 125                             Bobii Frutii珍珠水果特調
# 2528                                        誠品信義書店
# 2640                                       錢櫃台北敦南店
# 411                             Maccha House 敦南抹茶館
# 738                                       W Taipei
# 163                               Chimac175 Taipei
# 1189                             台北小巨蛋 如果 田馥甄巡迴演唱會
# 209                               Drip Cafe 好滴 松菸店
# 684                    Toasteria Cafe 3號 敦南 Dunnan
# 310                                    Ice Monster
#
#                                                   emoji  \
# 634   [(❤, 1458), (😂, 1223), (😭, 1125), (😍, 962), (💕...       ❤     1458
# 2831  [(🐷, 3324), (😂, 1091), (😋, 1056), (🐽, 695), (❤...       🐷     3324
# 1908  [(😂, 1194), (❤, 1026), (💕, 541), (😍, 530), (😭,...       😂     1194
# 490   [(😋, 1038), (😂, 949), (❤, 774), (💕, 692), (🍕, ...       😋     1038
# 785   [(😂, 802), (❤, 755), (😋, 748), (💕, 680), (🐼, 6...       😂      802
# 398   [(💑, 1052), (💓, 712), (☎, 635), (👇, 602), (❤, ...       💑     1052
# 1690  [(❤, 738), (😂, 666), (😍, 446), (💕, 311), (✨, 2...       ❤      738
# 2741  [(😂, 970), (😋, 662), (😍, 442), (❤, 407), (👍, 2...       😂      970
# 1252  [(😂, 795), (❤, 660), (😍, 297), (💕, 254), (😭, 2...       😂      795
# 2298  [(❤, 599), (🎄, 598), (😂, 516), (💕, 324), (😍, 2...       ❤      599
# 584   [(☁, 588), (❤, 586), (😋, 351), (💕, 349), (😂, 2...       ☁      588
# 1361  [(😂, 651), (❤, 576), (💕, 356), (☀, 283), (😭, 2...       😂      651
# 483   [(🌹, 1079), (🍦, 570), (😋, 201), (❤, 192), (💕, ...       🌹     1079
# 1322  [(🍵, 1245), (😍, 539), (😋, 528), (❤, 475), (💚, ...       🍵     1245
# 213   [(😂, 546), (❤, 495), (🍾, 339), (🙌, 273), (💕, 2...       😂      546
# 1779  [(😂, 532), (❤, 441), (😍, 398), (💕, 268), (😋, 2...       😂      532
# 1385  [(😂, 461), (❤, 440), (✨, 255), (🎉, 240), (😍, 2...       😂      461
# 414   [(❤, 643), (🎄, 440), (✨, 378), (😂, 298), (😍, 2...       ❤      643
# 142   [(🎄, 1018), (❤, 417), (😂, 382), (✨, 339), (🎅, ...       🎄     1018
# 1166  [(❤, 480), (🔥, 410), (😂, 398), (🌃, 375), (😍, 3...       ❤      480
# 615   [(😋, 541), (❤, 408), (💕, 240), (😂, 208), (😍, 2...       😋      541
# 2054  [(❤, 470), (💕, 403), (🍰, 399), (😋, 393), (😂, 3...       ❤      470
# 577   [(😋, 443), (❤, 403), (😍, 235), (😂, 231), (🍴, 1...       😋      443
# 125   [(💕, 411), (🍹, 397), (😂, 390), (❤, 333), (😋, 3...       💕      411
# 2528  [(😂, 607), (❤, 396), (😍, 343), (💕, 211), (😭, 1...       😂      607
# 2640  [(🎤, 424), (😂, 390), (❤, 299), (🎂, 110), (🍻, 1...       🎤      424
# 411   [(🍵, 933), (😂, 377), (❤, 341), (😋, 318), (😍, 2...       🍵      933
# 738   [(❤, 771), (😂, 362), (💕, 295), (😍, 288), (✨, 2...       ❤      771
# 163   [(❤, 354), (😂, 349), (😋, 346), (💕, 256), (🍗, 2...       ❤      354
# 1189  [(❤, 658), (😍, 347), (😂, 280), (💕, 206), (😭, 1...       ❤      658
# 209   [(❤, 332), (😋, 326), (🍓, 279), (😂, 223), (😍, 1...       ❤      332
# 684   [(❤, 367), (😂, 324), (😋, 281), (💕, 212), (🍴, 1...       ❤      367
# 310   [(🍧, 736), (😋, 321), (❤, 220), (😂, 217), (🍨, 2...       🍧      736
#
#      1_emoji  1_value 2_emoji  2_value 3_emoji  3_value 4_emoji  4_value
# 94         ❄     2933       😂     2268       ❤     2094       ⛄     1643
# 628        ❤     1721       😂     1513       😍      844       🎉      759
# 59         ❤     1590       💕      852       😭      796       😍      789
# 996        ❤     1321       🎄      950       💕      593       😍      490
# 634        😂     1223       😭     1125       😍      962       💕      848
# 2831       😂     1091       😋     1056       🐽      695       ❤      683
# 1908       ❤     1026       💕      541       😍      530       😭      432
# 490        😂      949       ❤      774       💕      692       🍕      673
# 785        ❤      755       😋      748       💕      680       🐼      611
# 398        💓      712       ☎      635       👇      602       ❤      560
# 1690       😂      666       😍      446       💕      311       ✨      294
# 2741       😋      662       😍      442       ❤      407       👍      286
# 1252       ❤      660       😍      297       💕      254       😭      253
# 2298       🎄      598       😂      516       💕      324       😍      265
# 584        ❤      586       😋      351       💕      349       😂      279
# 1361       ❤      576       💕      356       ☀      283       😭      238
# 483        🍦      570       😋      201       ❤      192       💕      171
# 1322       😍      539       😋      528       ❤      475       💚      379
# 213        ❤      495       🍾      339       🙌      273       💕      250
# 1779       ❤      441       😍      398       💕      268       😋      230
# 1385       ❤      440       ✨      255       🎉      240       😍      228
# 414        🎄      440       ✨      378       😂      298       😍      265
# 142        ❤      417       😂      382       ✨      339       🎅      296
# 1166       🔥      410       😂      398       🌃      375       😍      320
# 615        ❤      408       💕      240       😂      208       😍      206
# 2054       💕      403       🍰      399       😋      393       😂      381
# 577        ❤      403       😍      235       😂      231       🍴      198
# 125        🍹      397       😂      390       ❤      333       😋      300
# 2528       ❤      396       😍      343       💕      211       😭      193
# 2640       😂      390       ❤      299       🎂      110       🍻      103
# 411        😂      377       ❤      341       😋      318       😍      241
# 738        😂      362       💕      295       😍      288       ✨      233
# 163        😂      349       😋      346       💕      256       🍗      238
# 1189       😍      347       😂      280       💕      206       😭      154
# 209        😋      326       🍓      279       😂      223       😍      170
# 684        😂      324       😋      281       💕      212       🍴      185
# 310        😋      321       ❤      220       😂      217       🍨      214

# %% [markdown]
# # Where is the "😍"

# %%
ig_emoji[ ig_emoji.most_emoji == '😍' ]
# Out:
#                                      location_name  \
# 273                        HELLO KITTY Shabu-Shabu
# 638                       TORUK - The First Flight
# 2311                                   繪本咖啡｜嬉々café
# 2782                                           魚道生
# 525                                Peanuts專櫃-微風松高店
# 1805                                          旬採鮨処
# 2489                                       蓮香齋素食餐廳
# 1739                                         我樂制作所
# 465                                        N+n 喫早餐
# 1607                          小間咖啡酒館 Le Petit Café
# 1984                                     櫻桃小丸子主題餐廳
# 358                                   La LUPA 羅馬義廚
# 1314                        吾獨食驗室 Woo Doo Food Lab
# 101                                    BMW 台北鎔德旗艦店
# 705                                       Tùng Sơn
